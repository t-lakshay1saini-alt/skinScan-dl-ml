# %% [markdown]
# # SkinScan AI - Training on Google Colab
#
# This notebook clones the project repo, installs dependencies, downloads data, and runs the full training pipeline on Colab's GPU.
#
# **Steps:**
# 1. Enable GPU: Runtime -> Change runtime type -> GPU (T4)
# 2. Run all cells
# 3. After training completes, download the `models/` folder or push to GitHub

# %%
# Verify GPU is available
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices('GPU'))
assert len(tf.config.list_physical_devices('GPU')) > 0, "No GPU found! Enable GPU in Runtime settings."

# %%
# Clone the project repository
# !git clone https://github.com/lakshaysaini-hub/skinCance_dl_ml_repo.git project
# %cd project

# %%
# Install project dependencies
# !pip install -r requirements.txt -q

# %%
# Setup Kaggle API key
# Option A: Upload kaggle.json manually using the file browser on the left
# Option B: Paste your credentials here:
import os
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)

# Uncomment and fill in your credentials:
# import json
# kaggle_creds = {"username": "YOUR_USERNAME", "key": "YOUR_KEY"}
# with open(os.path.expanduser('~/.kaggle/kaggle.json'), 'w') as f:
#     json.dump(kaggle_creds, f)
# !chmod 600 ~/.kaggle/kaggle.json

# Option C: Upload the file
from google.colab import files
uploaded = files.upload()  # Upload kaggle.json
# !mv kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download the HAM10000 dataset
# !python scripts/download_data.py

# %%
# Run the full training pipeline (3-phase fine-tuning)
# !python src/train.py

# %%
# Run evaluation on the test set
# !python src/evaluate.py

# %%
# Train the OOD detector using embeddings from the trained model
# !python src/ood.py

# %%
# Download trained artifacts to your local machine
import shutil
shutil.make_archive('trained_artifacts', 'zip', '.', 'models')
shutil.make_archive('report_figures', 'zip', '.', 'report_figures')

from google.colab import files
files.download('trained_artifacts.zip')
files.download('report_figures.zip')
